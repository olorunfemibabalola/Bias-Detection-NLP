# %% [markdown]
# <a href="https://colab.research.google.com/github/olorunfemibabalola/Bias-Detection-NLP/blob/main/Bias_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **GENDER BIAS DETECTION PROJECT**
#
#
# This will be the markdown file outlying all the requirements for this project
#
# I will use a standard SDLC template here

# %% [markdown]
# Import Modeules

# %% [markdown]
# Import the Dataset

# %% [markdown]
# Exploratory Data Analysis

# %% [markdown]
# Clean the Data

# %% [markdown]
# Split into Training and Testing Sets

# %% [markdown]
# Create a model

# %% [markdown]
# Train the Model

# %% [markdown]
# Make Predictions

# %% [markdown]
# Evaluate and Improve the Model

# %% [markdown]
# Make more Predictions

# %% [markdown]
# Persisting Models

# %% [markdown]
# Load Your Saved Model
