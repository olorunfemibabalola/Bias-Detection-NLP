# %% [markdown]
# <a href="https://colab.research.google.com/github/olorunfemibabalola/Gender-Bias-Detection-NLP/blob/main/Gender_Bias_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **GENDER BIAS DETECTION PROJECT**
#
#
# This will be the markdown file outlying all the requirements for this project
#
# I will use a standard SDLC template here

# %%
generate a code for me
# Out:
#   File "/tmp/ipython-input-742211228.py", line 1
#     generate a code for me
#              ^
# SyntaxError: invalid syntax
